# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

# %%
dataset= pd.read_excel("/Users/anamika/Desktop/Anamika/DataAnalyst_NINJA/Python_hackathon_jan2023/HospitalDatabase.xlsx")

# %%
dataset
# Out:
#      PatientID FirstName  LastName             DateOfBirth Gender  \
# 0            1     Lanni       Sue 1960-01-01 00:00:00.000   Male
# 1            2       Far     Myers 1985-11-15 02:08:42.090   Male
# 2            3   Devlin    Michael 1976-04-15 02:52:09.762   Male
# 3            4   Carmine     Texas 1968-10-15 03:32:13.635   Male
# 4            5     Tann       Bama 1962-05-01 19:12:58.950   Male
# ..         ...       ...       ...                     ...    ...
# 940        941       Wat   Fideler 1986-05-26 00:01:19.761   Male
# 941        942    Wandie  Baythrop 1970-06-10 21:41:03.814   Male
# 942        943   Diahann   Smeeton 1983-01-08 21:49:27.884   Male
# 943        944  Panchito   Sharple 1963-06-05 07:57:05.569   Male
# 944        945     Walsh    Calvie 1972-08-06 03:40:03.454   Male
#
#                        Race Language
# 0                     White  English
# 1                     White  English
# 2                     White  English
# ...

# %%
print(pd.get_dataset_names())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_r/5qc9c15d6dv412dkxf7tqbx40000gn/T/ipykernel_9059/831321058.py in <module>
# ----> 1 print(pd.get_dataset_names())
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/__init__.py in __getattr__(name)
#     259         return _SparseArray
#     260
# --> 261     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     262
#     263
#
# AttributeError: module 'pandas' has no attribute 'get_dataset_names'

# %%
pwd
# Out:
# '/Users/anamika/Desktop/Anamika/DataAnalyst_NINJA/Python Classes/Notes_Python'

# %%
ds_read_regis =pd.read_excel("/Users/anamika/Desktop/Anamika/DataAnalyst_NINJA/Python_hackathon_jan2023/HospitalDatabase.xlsx", sheet_name="ReAdmissionRegistry")

# %%
ds_read_regis
# Out:
#      AdmissionID  PatientID AdmissionDate           DischargeDate  \
# 0            389          1    2018-01-01 2018-01-04 19:59:31.391
# 1            635          2    2018-01-01 2018-01-04 21:28:51.898
# 2            606          3    2018-01-01 2018-01-04 22:28:23.672
# 3            587          5    2018-01-01 2018-01-05 05:47:04.933
# 4            640          6    2018-01-01 2018-01-05 14:18:30.029
# ..           ...        ...           ...                     ...
# 715          521        738    2018-02-22 2018-03-07 21:22:10.061
# 716          548        739    2018-02-22 2018-03-08 02:43:18.749
# 717          509        740    2018-02-22 2018-03-08 09:27:18.377
# 718          605        741    2018-02-22 2018-03-10 06:06:12.068
# 719          710        742    2018-02-22 2018-03-10 20:38:30.568
#
#     DischargeDisposition           Service PrimaryDiagnosis  ExpectedLOS  \
# 0                   Home       Hospitalist   Kidney Failure     6.717771
# ...

# %%
hosp_path="/Users/anamika/Desktop/Anamika/DataAnalyst_NINJA/Python_hackathon_jan2023/HospitalDatabase.xlsx"
hosp_sheet=pd.read_excel(hosp_path)

# %%
hosp_sheet
# Out:
#      PatientID FirstName  LastName             DateOfBirth Gender  \
# 0            1     Lanni       Sue 1960-01-01 00:00:00.000   Male
# 1            2       Far     Myers 1985-11-15 02:08:42.090   Male
# 2            3   Devlin    Michael 1976-04-15 02:52:09.762   Male
# 3            4   Carmine     Texas 1968-10-15 03:32:13.635   Male
# 4            5     Tann       Bama 1962-05-01 19:12:58.950   Male
# ..         ...       ...       ...                     ...    ...
# 940        941       Wat   Fideler 1986-05-26 00:01:19.761   Male
# 941        942    Wandie  Baythrop 1970-06-10 21:41:03.814   Male
# 942        943   Diahann   Smeeton 1983-01-08 21:49:27.884   Male
# 943        944  Panchito   Sharple 1963-06-05 07:57:05.569   Male
# 944        945     Walsh    Calvie 1972-08-06 03:40:03.454   Male
#
#                        Race Language
# 0                     White  English
# 1                     White  English
# 2                     White  English
# ...

# %%
ds_read_regis=pd.read_excel(hosp_path, sheet_name="ReAdmissionRegistry")

# %%
service=ds_read_regis.Service

# %%
service
# Out:
# 0           Hospitalist
# 1      General Medicine
# 2      General Medicine
# 3      General Medicine
# 4                   ICU
#              ...
# 715          Cardiology
# 716                 ICU
# 717         Hospitalist
# 718    General Medicine
# 719    General Medicine
# Name: Service, Length: 720, dtype: object

# %% [markdown]
# ###### 11. Create a pie chart by taking Service= ["ICU", "Neurology", "General", "Medicine"] & ExpectedLOS=[10,5,7,9] & explode the wedge with highest LOS.

# %%
los = np.array([10, 5, 7, 9])
plt.pie(los)
service = ["ICU", "Neurology", "General", "Medicine"]

myexplode = [0.2, 0, 0, 0]#Pull the "ICU" wedge 0.2 from the center of the pie:


#plt.pie(y, labels = mylabels)
plt.pie(los, labels = service, explode = myexplode)

plt.show()

# %%
pip install psycopg2-binary
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 11.0 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.4/352.4 kB 4.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 962.4/962.4 kB 9.7 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import psycopg2 as ps
import pandas as pd
conn = ps.connect(
    host=os.environ["db_host"],
    port=os.environ["db_port"],
    dbname=os.environ["db_name"],
    user=os.environ["db_user"],
    password=os.environ["db_password"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_r/5qc9c15d6dv412dkxf7tqbx40000gn/T/ipykernel_9059/2891043565.py in <module>
#       3 import pandas as pd
#       4 conn = ps.connect(
# ----> 5     host=os.environ["db_host"],
#       6     port=os.environ["db_port"],
#       7     dbname=os.environ["db_name"],
#
# ~/opt/anaconda3/lib/python3.9/os.py in __getitem__(self, key)
#     677         except KeyError:
#     678             # raise KeyError with the original key value
# --> 679             raise KeyError(key) from None
#     680         return self.decodevalue(value)
#     681
#
# KeyError: 'db_host'

# %% [markdown]
# ###### 13.  Create a subplot on x = np.arange(0, 10, 0.1) , y = np.sin(np.pi * x) + x with 2 rows & 2 columns with object oriented approach.

# %%
x = np.arange(0, 10, 0.1)

# %%
y = np.sin(np.pi * x) + x

# %%
x = np.arange(0, 10, 0.1)
y = np.sin(np.pi * x) + x

#Object-Oriented Approach — plt.subplots()
fig, ax = plt.subplots(2,2)
fig.set_facecolor('lightgrey')
ax[0,0].plot(x, y, 'r-')
ax[0,1].plot(x, y, 'b-')
ax[1,0].plot(x, y, 'y-')
ax[1,1].plot(x, y, 'g-')
fig.suptitle("2 x 2 with Object-Oriented Approach")
# Out:
# Text(0.5, 0.98, '2 x 2 with Object-Oriented Approach')
